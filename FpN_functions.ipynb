# %% [markdown]
# Генерация FP 4 - таблиц но без ieee-754

# %%
BIAS = 1
EMIN = -1   
EMAX =  2   


def fp4_to_float(x: int) -> float:
    sign = (x >> 3) & 0b1
    exp_bits = (x >> 1) & 0b11
    frac = x & 0b1

    if exp_bits == 0 and frac == 0:
        return 0.0 * (-1) ** sign

    E = exp_bits - BIAS
    mant = 1.0 + frac * 0.5
    return ((-1) ** sign) * mant * (2 ** E)

# %%
for x in range(1 << 4):
    print(bin(x), fp4_to_float(x))
# Out:
# 0b0 0.0
# 0b1 0.75
# 0b10 1.0
# 0b11 1.5
# 0b100 2.0
# 0b101 3.0
# 0b110 4.0
# 0b111 6.0
# 0b1000 -0.0
# 0b1001 -0.75
# 0b1010 -1.0
# 0b1011 -1.5
# 0b1100 -2.0
# 0b1101 -3.0
# 0b1110 -4.0
# 0b1111 -6.0

# %%
import math

def fp4_to_float_ieee_754(x: int) -> float:
    sign = (x >> 3) & 0b1
    exp_bits = (x >> 1) & 0b11
    frac = x & 0b1

    if exp_bits == 0 and frac == 0:
        return 0.0 * (-1) ** sign
    
    if exp_bits == 0b11:
        if frac == 0:
            return -math.inf if sign else math.inf
        else:
            return float("nan")

    E = exp_bits - BIAS
    mant = 1.0 + frac * 0.5
    return ((-1) ** sign) * mant * (2 ** E)

# %%
for x in range(1 << 4):
    print(bin(x), fp4_to_float_ieee_754(x))
# Out:
# 0b0 0.0
# 0b1 0.75
# 0b10 1.0
# 0b11 1.5
# 0b100 2.0
# 0b101 3.0
# 0b110 inf
# 0b111 nan
# 0b1000 -0.0
# 0b1001 -0.75
# 0b1010 -1.0
# 0b1011 -1.5
# 0b1100 -2.0
# 0b1101 -3.0
# 0b1110 -inf
# 0b1111 nan

# %%
def decode_fp4(x: int):
    """FP4  (sign - 1, E - 2, mant_int - 1)
    """
    sign = (x >> 3) & 0b1
    exp_bits = (x >> 1) & 0b11
    frac = x & 0b1

    # Ноль: 0000
    if exp_bits == 0 and frac == 0:
        return sign, None, 0  #zero

    E = exp_bits - BIAS        
    mant_int = 2 + frac           
    return sign, E, mant_int


def encode_fp4(sign: int, E: int, mant_int: int) -> int:
   
    # zero
    if mant_int == 0:
        return 0

   
   
    
    while mant_int >= 4 and E < EMAX:
        mant_int >>= 1
        E += 1

    while mant_int > 0 and mant_int < 2 and E > EMIN:
        mant_int <<= 1
        E -= 1

    #infty
    if E > EMAX:
        exp_bits = 0b11
        frac = 0
        return (sign << 3) | (exp_bits << 1) | frac

    #zero-eps
    if E < EMIN:
        return 0

    exp_bits = E + BIAS
    frac = mant_int - 2  
    return (sign << 3) | (exp_bits << 1) | frac


def add_fp4(a: int, b: int) -> int:
    
    signA, EA, mantA = decode_fp4(a)
    signB, EB, mantB = decode_fp4(b)

    if mantA == 0:
        return b
    if mantB == 0:
        return a

    
    if EA > EB:
        d = EA - EB
        mantB >>= d 
        EB = EA
        E = EA
    elif EB > EA:
        d = EB - EA
        mantA >>= d
        EA = EB
        E = EB
    else:
        E = EA  

   
    valA = mantA * (-1) ** signA
    valB = mantB * (-1) ** signB
    res = valA + valB

    
    if res == 0:
        return 0

    sign_res = 0 if res > 0 else 1
    mant_res = abs(res)

    
    return encode_fp4(sign_res, E, mant_res)


def sub_fp4(a: int, b: int) -> int:
    b_neg = b ^ 0b1000
    return add_fp4(a, b_neg)


def mul_fp4(a: int, b: int) -> int:
    signA, EA, mantA = decode_fp4(a)
    signB, EB, mantB = decode_fp4(b)

    if mantA == 0 or mantB == 0:
        return 0

    sign_res = signA ^ signB
    E_res = EA + EB - 1
    mant_res = mantA * mantB

    return encode_fp4(sign_res, E_res, mant_res)


def div_fp4(a: int, b: int) -> int:
    signA, EA, mantA = decode_fp4(a)
    signB, EB, mantB = decode_fp4(b)

    if mantA == 0:
        return 0

    if mantB == 0:
        sign_res = signA ^ signB
        exp_bits = 0b11
        frac = 0
        return (sign_res << 3) | (exp_bits << 1) | frac

    sign_res = signA ^ signB
    mant_res = (mantA << 1) // mantB
    E_res = EA - EB

    return encode_fp4(sign_res, E_res, mant_res)

# %%
for a in range(0, 1 << 4):
    for b in range(1 << 4):
        print(fp4_to_float(a), fp4_to_float(b),
               fp4_to_float(add_fp4(a, b)))
        print(bin(a), bin(b), bin(add_fp4(a, b)))
        print("----------")
# Out:
# 0.0 0.0 0.0
# 0b0 0b0 0b0
# ----------
# 0.0 0.75 0.75
# 0b0 0b1 0b1
# ----------
# 0.0 1.0 1.0
# 0b0 0b10 0b10
# ----------
# 0.0 1.5 1.5
# 0b0 0b11 0b11
# ----------
# 0.0 2.0 2.0
# 0b0 0b100 0b100
# ----------
# 0.0 3.0 3.0
# 0b0 0b101 0b101
# ----------
# 0.0 4.0 4.0
# 0b0 0b110 0b110
# ----------
# 0.0 6.0 6.0
# 0b0 0b111 0b111
# ----------
# 0.0 -0.0 -0.0
# 0b0 0b1000 0b1000
# ----------
# 0.0 -0.75 -0.75
# 0b0 0b1001 0b1001
# ----------
# 0.0 -1.0 -1.0
# 0b0 0b1010 0b1010
# ----------
# 0.0 -1.5 -1.5
# 0b0 0b1011 0b1011
# ----------
# 0.0 -2.0 -2.0
# 0b0 0b1100 0b1100
# ----------
# 0.0 -3.0 -3.0
# 0b0 0b1101 0b1101
# ----------
# 0.0 -4.0 -4.0
# 0b0 0b1110 0b1110
# ----------
# 0.0 -6.0 -6.0
# 0b0 0b1111 0b1111
# ----------
# 0.75 0.0 0.75
# 0b1 0b0 0b1
# ----------
# 0.75 0.75 1.5
# 0b1 0b1 0b11
# ----------
# 0.75 1.0 1.5
# 0b1 0b10 0b11
# ----------
# 0.75 1.5 2.0
# 0b1 0b11 0b100
# ----------
# 0.75 2.0 2.0
# 0b1 0b100 0b100
# ----------
# 0.75 3.0 3.0
# 0b1 0b101 0b101
# ----------
# 0.75 4.0 4.0
# 0b1 0b110 0b110
# ----------
# 0.75 6.0 6.0
# 0b1 0b111 0b111
# ----------
# 0.75 -0.0 0.75
# 0b1 0b1000 0b1
# ----------
# 0.75 -0.75 0.0
# 0b1 0b1001 0b0
# ----------
# 0.75 -1.0 -0.0
# 0b1 0b1010 0b1000
# ----------
# 0.75 -1.5 -1.0
# 0b1 0b1011 0b1010
# ----------
# 0.75 -2.0 -2.0
# 0b1 0b1100 0b1100
# ----------
# 0.75 -3.0 -3.0
# 0b1 0b1101 0b1101
# ----------
# 0.75 -4.0 -4.0
# 0b1 0b1110 0b1110
# ----------
# 0.75 -6.0 -6.0
# 0b1 0b1111 0b1111
# ----------
# 1.0 0.0 1.0
# 0b10 0b0 0b10
# ----------
# 1.0 0.75 1.5
# 0b10 0b1 0b11
# ----------
# 1.0 1.0 2.0
# 0b10 0b10 0b100
# ----------
# 1.0 1.5 2.0
# 0b10 0b11 0b100
# ----------
# 1.0 2.0 3.0
# 0b10 0b100 0b101
# ----------
# 1.0 3.0 4.0
# 0b10 0b101 0b110
# ----------
# 1.0 4.0 4.0
# 0b10 0b110 0b110
# ----------
# 1.0 6.0 6.0
# 0b10 0b111 0b111
# ----------
# 1.0 -0.0 1.0
# 0b10 0b1000 0b10
# ----------
# 1.0 -0.75 0.0
# 0b10 0b1001 0b0
# ----------
# 1.0 -1.0 0.0
# 0b10 0b1010 0b0
# ----------
# 1.0 -1.5 -0.0
# 0b10 0b1011 0b1000
# ----------
# 1.0 -2.0 -1.0
# 0b10 0b1100 0b1010
# ----------
# 1.0 -3.0 -2.0
# 0b10 0b1101 0b1100
# ----------
# 1.0 -4.0 -4.0
# 0b10 0b1110 0b1110
# ----------
# 1.0 -6.0 -6.0
# 0b10 0b1111 0b1111
# ----------
# 1.5 0.0 1.5
# 0b11 0b0 0b11
# ----------
# 1.5 0.75 2.0
# 0b11 0b1 0b100
# ----------
# 1.5 1.0 2.0
# 0b11 0b10 0b100
# ----------
# 1.5 1.5 3.0
# 0b11 0b11 0b101
# ----------
# 1.5 2.0 3.0
# 0b11 0b100 0b101
# ----------
# 1.5 3.0 4.0
# 0b11 0b101 0b110
# ----------
# 1.5 4.0 4.0
# 0b11 0b110 0b110
# ----------
# 1.5 6.0 6.0
# 0b11 0b111 0b111
# ----------
# 1.5 -0.0 1.5
# 0b11 0b1000 0b11
# ----------
# 1.5 -0.75 1.0
# 0b11 0b1001 0b10
# ----------
# 1.5 -1.0 0.0
# 0b11 0b1010 0b0
# ----------
# 1.5 -1.5 0.0
# 0b11 0b1011 0b0
# ----------
# 1.5 -2.0 -1.0
# 0b11 0b1100 0b1010
# ----------
# 1.5 -3.0 -2.0
# 0b11 0b1101 0b1100
# ----------
# 1.5 -4.0 -4.0
# 0b11 0b1110 0b1110
# ----------
# 1.5 -6.0 -6.0
# 0b11 0b1111 0b1111
# ----------
# 2.0 0.0 2.0
# 0b100 0b0 0b100
# ----------
# 2.0 0.75 2.0
# 0b100 0b1 0b100
# ----------
# 2.0 1.0 3.0
# 0b100 0b10 0b101
# ----------
# 2.0 1.5 3.0
# 0b100 0b11 0b101
# ----------
# 2.0 2.0 4.0
# 0b100 0b100 0b110
# ----------
# 2.0 3.0 4.0
# 0b100 0b101 0b110
# ----------
# 2.0 4.0 6.0
# 0b100 0b110 0b111
# ----------
# 2.0 6.0 4.0
# 0b100 0b111 0b110
# ----------
# 2.0 -0.0 2.0
# 0b100 0b1000 0b100
# ----------
# 2.0 -0.75 2.0
# 0b100 0b1001 0b100
# ----------
# 2.0 -1.0 1.0
# 0b100 0b1010 0b10
# ----------
# 2.0 -1.5 1.0
# 0b100 0b1011 0b10
# ----------
# 2.0 -2.0 0.0
# 0b100 0b1100 0b0
# ----------
# 2.0 -3.0 -1.0
# 0b100 0b1101 0b1010
# ----------
# 2.0 -4.0 -2.0
# 0b100 0b1110 0b1100
# ----------
# 2.0 -6.0 -4.0
# 0b100 0b1111 0b1110
# ----------
# 3.0 0.0 3.0
# 0b101 0b0 0b101
# ----------
# 3.0 0.75 3.0
# 0b101 0b1 0b101
# ----------
# 3.0 1.0 4.0
# 0b101 0b10 0b110
# ----------
# 3.0 1.5 4.0
# 0b101 0b11 0b110
# ----------
# 3.0 2.0 4.0
# 0b101 0b100 0b110
# ----------
# 3.0 3.0 6.0
# 0b101 0b101 0b111
# ----------
# 3.0 4.0 6.0
# 0b101 0b110 0b111
# ----------
# 3.0 6.0 4.0
# 0b101 0b111 0b110
# ----------
# 3.0 -0.0 3.0
# 0b101 0b1000 0b101
# ----------
# 3.0 -0.75 3.0
# 0b101 0b1001 0b101
# ----------
# 3.0 -1.0 2.0
# 0b101 0b1010 0b100
# ----------
# 3.0 -1.5 2.0
# 0b101 0b1011 0b100
# ----------
# 3.0 -2.0 1.0
# 0b101 0b1100 0b10
# ----------
# 3.0 -3.0 0.0
# 0b101 0b1101 0b0
# ----------
# 3.0 -4.0 -2.0
# 0b101 0b1110 0b1100
# ----------
# 3.0 -6.0 -4.0
# 0b101 0b1111 0b1110
# ----------
# 4.0 0.0 4.0
# 0b110 0b0 0b110
# ----------
# 4.0 0.75 4.0
# 0b110 0b1 0b110
# ----------
# 4.0 1.0 4.0
# 0b110 0b10 0b110
# ----------
# 4.0 1.5 4.0
# 0b110 0b11 0b110
# ----------
# 4.0 2.0 6.0
# 0b110 0b100 0b111
# ----------
# 4.0 3.0 6.0
# 0b110 0b101 0b111
# ----------
# 4.0 4.0 4.0
# 0b110 0b110 0b110
# ----------
# 4.0 6.0 6.0
# 0b110 0b111 0b111
# ----------
# 4.0 -0.0 4.0
# 0b110 0b1000 0b110
# ----------
# 4.0 -0.75 4.0
# 0b110 0b1001 0b110
# ----------
# 4.0 -1.0 4.0
# 0b110 0b1010 0b110
# ----------
# 4.0 -1.5 4.0
# 0b110 0b1011 0b110
# ----------
# 4.0 -2.0 2.0
# 0b110 0b1100 0b100
# ----------
# 4.0 -3.0 2.0
# 0b110 0b1101 0b100
# ----------
# 4.0 -4.0 0.0
# 0b110 0b1110 0b0
# ----------
# 4.0 -6.0 -2.0
# 0b110 0b1111 0b1100
# ----------
# 6.0 0.0 6.0
# 0b111 0b0 0b111
# ----------
# 6.0 0.75 6.0
# 0b111 0b1 0b111
# ----------
# 6.0 1.0 6.0
# 0b111 0b10 0b111
# ----------
# 6.0 1.5 6.0
# 0b111 0b11 0b111
# ----------
# 6.0 2.0 4.0
# 0b111 0b100 0b110
# ----------
# 6.0 3.0 4.0
# 0b111 0b101 0b110
# ----------
# 6.0 4.0 6.0
# 0b111 0b110 0b111
# ----------
# 6.0 6.0 4.0
# 0b111 0b111 0b110
# ----------
# 6.0 -0.0 6.0
# 0b111 0b1000 0b111
# ----------
# 6.0 -0.75 6.0
# 0b111 0b1001 0b111
# ----------
# 6.0 -1.0 6.0
# 0b111 0b1010 0b111
# ----------
# 6.0 -1.5 6.0
# 0b111 0b1011 0b111
# ----------
# 6.0 -2.0 4.0
# 0b111 0b1100 0b110
# ----------
# 6.0 -3.0 4.0
# 0b111 0b1101 0b110
# ----------
# 6.0 -4.0 2.0
# 0b111 0b1110 0b100
# ----------
# 6.0 -6.0 0.0
# 0b111 0b1111 0b0
# ----------
# -0.0 0.0 0.0
# 0b1000 0b0 0b0
# ----------
# -0.0 0.75 0.75
# 0b1000 0b1 0b1
# ----------
# -0.0 1.0 1.0
# 0b1000 0b10 0b10
# ----------
# -0.0 1.5 1.5
# 0b1000 0b11 0b11
# ----------
# -0.0 2.0 2.0
# 0b1000 0b100 0b100
# ----------
# -0.0 3.0 3.0
# 0b1000 0b101 0b101
# ----------
# -0.0 4.0 4.0
# 0b1000 0b110 0b110
# ----------
# -0.0 6.0 6.0
# 0b1000 0b111 0b111
# ----------
# -0.0 -0.0 -0.0
# 0b1000 0b1000 0b1000
# ----------
# -0.0 -0.75 -0.75
# 0b1000 0b1001 0b1001
# ----------
# -0.0 -1.0 -1.0
# 0b1000 0b1010 0b1010
# ----------
# -0.0 -1.5 -1.5
# 0b1000 0b1011 0b1011
# ----------
# -0.0 -2.0 -2.0
# 0b1000 0b1100 0b1100
# ----------
# -0.0 -3.0 -3.0
# 0b1000 0b1101 0b1101
# ----------
# -0.0 -4.0 -4.0
# 0b1000 0b1110 0b1110
# ----------
# -0.0 -6.0 -6.0
# 0b1000 0b1111 0b1111
# ----------
# -0.75 0.0 -0.75
# 0b1001 0b0 0b1001
# ----------
# -0.75 0.75 0.0
# 0b1001 0b1 0b0
# ----------
# -0.75 1.0 0.0
# 0b1001 0b10 0b0
# ----------
# -0.75 1.5 1.0
# 0b1001 0b11 0b10
# ----------
# -0.75 2.0 2.0
# 0b1001 0b100 0b100
# ----------
# -0.75 3.0 3.0
# 0b1001 0b101 0b101
# ----------
# -0.75 4.0 4.0
# 0b1001 0b110 0b110
# ----------
# -0.75 6.0 6.0
# 0b1001 0b111 0b111
# ----------
# -0.75 -0.0 -0.75
# 0b1001 0b1000 0b1001
# ----------
# -0.75 -0.75 -1.5
# 0b1001 0b1001 0b1011
# ----------
# 0b1110 0b1100 0b1111
# ----------
# -4.0 -3.0 -6.0
# 0b1110 0b1101 0b1111
# ----------
# -4.0 -4.0 -4.0
# 0b1110 0b1110 0b1110
# ----------
# -4.0 -6.0 -6.0
# 0b1110 0b1111 0b1111
# ----------
# -6.0 0.0 -6.0
# 0b1111 0b0 0b1111
# ----------
# -6.0 0.75 -6.0
# 0b1111 0b1 0b1111
# ----------
# -6.0 1.0 -6.0
# 0b1111 0b10 0b1111
# ----------
# -6.0 1.5 -6.0
# 0b1111 0b11 0b1111
# ----------
# -6.0 2.0 -4.0
# 0b1111 0b100 0b1110
# ----------
# -6.0 3.0 -4.0
# 0b1111 0b101 0b1110
# ----------
# -6.0 4.0 -2.0
# 0b1111 0b110 0b1100
# ----------
# -6.0 6.0 0.0
# 0b1111 0b111 0b0
# ----------
# -6.0 -0.0 -6.0
# 0b1111 0b1000 0b1111
# ----------
# -6.0 -0.75 -6.0
# 0b1111 0b1001 0b1111
# ----------
# -6.0 -1.0 -6.0
# 0b1111 0b1010 0b1111
# ----------
# -6.0 -1.5 -6.0
# 0b1111 0b1011 0b1111
# ----------
# -6.0 -2.0 -4.0
# 0b1111 0b1100 0b1110
# ----------
# -6.0 -3.0 -4.0
# 0b1111 0b1101 0b1110
# ----------
# -6.0 -4.0 -6.0
# 0b1111 0b1110 0b1111
# ----------
# -6.0 -6.0 -4.0
# 0b1111 0b1111 0b1110
# ----------

# %%
for a in range(0, 1 << 4):
    for b in range(1 << 4):
        # print(fp4_to_float(a), fp4_to_float(b),
        #        fp4_to_float(add_fp4(a, b)))
        # print(bin(a), bin(b), bin(add_fp4(a, b)))
        # print("----------")
        print(str(bin(add_fp4(a, b)))[-1], end = '')
# Out:
# 

# %%
for i in range(0,4):
    for a in range(0, 1 << 4):
        for b in range(1 << 4):
            # print(fp4_to_float(a), fp4_to_float(b),
            #        fp4_to_float(add_fp4(a, b)))
            # print(bin(a), bin(b), bin(add_fp4(a, b)))
            # print("----------")
            if (i + 2 >= len(str(bin(add_fp4(a, b))))):
                print(0, end='')
            else:
                print(str(bin(add_fp4(a, b)))[-(i + 1)], end='')
    print()
# Out:
# 
# 
# 
# 

# %%
def print_fp4_bit_vectors(op_func, op_name="op"):
    for bit in range(4):
        print(f"{op_name}[{bit}]: ", end="")

        for a in range(1 << 4):
            for b in range(1 << 4):
                result = op_func(a, b)
                value = (result >> bit) & 1
                print(value, end="")

        print()

# %%
print_fp4_bit_vectors(add_fp4, "add")
# Out:
# add[0]: 
# add[1]: 
# add[2]: 
# add[3]: 

# %%
print_fp4_bit_vectors(sub_fp4, "sub")
# Out:
# sub[0]: 
# sub[1]: 
# sub[2]: 
# sub[3]: 

# %%
print_fp4_bit_vectors(mul_fp4, "mul")
# Out:
# mul[0]: 
# mul[1]: 
# mul[2]: 
# mul[3]: 

# %%
print_fp4_bit_vectors(div_fp4, "div")
# Out:
# div[0]: 
# div[1]: 
# div[2]: 
# div[3]: 
